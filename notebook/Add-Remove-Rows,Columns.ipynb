# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')
pd.set_option('display.max_columns',5)
pd.set_option('display.max_rows', 5)

# %%
df
# Out:
#        Respondent                              MainBranch  \
# 0               1  I am a student who is learning to code
# 1               2  I am a student who is learning to code
# ...           ...                                     ...
# 88881       88816                                     NaN
# 88882       88863                                     NaN
#
#                   ...                       SurveyLength  \
# 0                 ...              Appropriate in length
# 1                 ...              Appropriate in length
# ...               ...                                ...
# 88881             ...                                NaN
# 88882             ...              Appropriate in length
#
#                        SurveyEase
# 0      Neither easy nor difficult
# 1      Neither easy nor difficult
# ...                           ...
# 88881                         NaN
# 88882                        Easy
#
# [88883 rows x 85 columns]

# %%
df.drop(columns=['Respondent'])   ##Remove the Respondent column and reflect the changes in DF
# Out:
#                                    MainBranch Hobbyist  \
# 0      I am a student who is learning to code      Yes
# 1      I am a student who is learning to code       No
# ...                                       ...      ...
# 88881                                     NaN       No
# 88882                                     NaN      Yes
#
#                   ...                       SurveyLength  \
# 0                 ...              Appropriate in length
# 1                 ...              Appropriate in length
# ...               ...                                ...
# 88881             ...                                NaN
# 88882             ...              Appropriate in length
#
#                        SurveyEase
# 0      Neither easy nor difficult
# 1      Neither easy nor difficult
# ...                           ...
# 88881                         NaN
# 88882                        Easy
#
# [88883 rows x 84 columns]

# %%
df['SurveyEase'].str.split(' ', expand=True)   ##Expanding the values of SurveyEase based on space.
# Out:
#              0     1     2          3
# 0      Neither  easy   nor  difficult
# 1      Neither  easy   nor  difficult
# ...        ...   ...   ...        ...
# 88881      NaN   NaN   NaN        NaN
# 88882     Easy  None  None       None
#
# [88883 rows x 4 columns]

# %%
df[['first', 'second', 'third','forth']] = df['SurveyEase'].str.split(' ', expand=True)  ##Adding new column
df
# Out:
#                                    MainBranch Hobbyist    ...     third  \
# 0      I am a student who is learning to code      Yes    ...       nor
# 1      I am a student who is learning to code       No    ...       nor
# ...                                       ...      ...    ...       ...
# 88881                                     NaN       No    ...       NaN
# 88882                                     NaN      Yes    ...      None
#
#            forth
# 0      difficult
# 1      difficult
# ...          ...
# 88881        NaN
# 88882       None
#
# [88883 rows x 88 columns]

# %%
df.drop(index=1)
# Out:
#                                               MainBranch Hobbyist    ...      \
# 0                 I am a student who is learning to code      Yes    ...
# 2      I am not primarily a developer, but I write co...      Yes    ...
# ...                                                  ...      ...    ...
# 88881                                                NaN       No    ...
# 88882                                                NaN      Yes    ...
#
#       third      forth
# 0       nor  difficult
# 2       nor  difficult
# ...     ...        ...
# 88881   NaN        NaN
# 88882  None       None
#
# [88882 rows x 88 columns]
