# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.set_index('YearsCode')     ##set 'YearsCode' as the index
# Out:
#                     Respondent  \
# YearsCode
# 4                            1
# NaN                          2
# 3                            3
# 3                            4
# 16                           5
# 13                           6
# 6                            7
# 8                            8
# 12                           9
# 12                          10
# 2                           11
# 5                           12
# 17                          13
# 13                          14
# 3                           15
# 10                          16
# 5                           17
# 10                          18
# 14                          19
# 8                           20
# 5                           21
# 35                          22
# 3                           23
# 2                           24
# 2                           25
# 12                          26
# 7                           27
# 10                          28
# ...

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
df.set_index('YearsCode', inplace=True)     ## Setting the inplace will show YearsCode in df

# %%
df
# Out:
#                     Respondent  \
# YearsCode
# 4                            1
# NaN                          2
# 3                            3
# 3                            4
# 16                           5
# 13                           6
# 6                            7
# 8                            8
# 12                           9
# 12                          10
# 2                           11
# 5                           12
# 17                          13
# 13                          14
# 3                           15
# 10                          16
# 5                           17
# 10                          18
# 14                          19
# 8                           20
# 5                           21
# 35                          22
# 3                           23
# 2                           24
# 2                           25
# 12                          26
# 7                           27
# 10                          28
# ...

# %%
df.index     ##Now the index has been changed to YearsCode
# Out:
# Index([ '4',  nan,  '3',  '3', '16', '13',  '6',  '8', '12', '12',
#        ...
#         nan,  nan,  '1', '18', '38',  nan,  nan,  nan,  nan,  '8'],
#       dtype='object', name='YearsCode', length=88883)

# %%
df.loc['4']    ## Now we can retrive rows which has YearsCode as 4
# Out:
#            Respondent                                         MainBranch  \
# YearsCode
# 4                   1             I am a student who is learning to code
# 4                  29                     I am a developer by profession
# 4                  41                     I am a developer by profession
# 4                  51             I am a student who is learning to code
# 4                  69                     I am a developer by profession
# 4                  71                     I am a developer by profession
# 4                 136                     I am a developer by profession
# 4                 140                     I am a developer by profession
# 4                 171             I am a student who is learning to code
# 4                 212                     I am a developer by profession
# 4                 270             I am a student who is learning to code
# 4                 282                     I am a developer by profession
# ...

# %%
df.iloc[0]  ## We can still use the iloc to fetch as per index
# Out:
# Respondent                                                        1
# MainBranch                   I am a student who is learning to code
# Hobbyist                                                        Yes
# OpenSourcer                                                   Never
# OpenSource        The quality of OSS and closed source software ...
# Employment                   Not employed, and not looking for work
# Country                                              United Kingdom
# Student                                                          No
# EdLevel                                   Primary/elementary school
# UndergradMajor                                                  NaN
# EduOther          Taught yourself a new language, framework, or ...
# OrgSize                                                         NaN
# DevType                                                         NaN
# Age1stCode                                                       10
# ...

# %%
df.reset_index(inplace=True)    ## Now we have origial index in place.
df
# Out:
#                 YearsCode  Respondent  \
# 0                       4           1
# 1                     NaN           2
# 2                       3           3
# 3                       3           4
# 4                      16           5
# 5                      13           6
# 6                       6           7
# 7                       8           8
# 8                      12           9
# 9                      12          10
# 10                      2          11
# 11                      5          12
# 12                     17          13
# 13                     13          14
# 14                      3          15
# 15                     10          16
# 16                      5          17
# 17                     10          18
# 18                     14          19
# 19                      8          20
# 20                      5          21
# 21                     35          22
# 22                      3          23
# ...

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows', 85)

# %%
df.head()   ##We have made Respondent as Index.
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_index() ## To sort it Alphabetical
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...

# %%
df.sort_index(ascending=False)  ##To revert the chanegs
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 88883                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88879                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88876                          I am a developer by profession      Yes
# 88875       I used to be a developer by profession, but no...      Yes
# 88874                          I am a developer by profession      Yes
# 88873                          I am a developer by profession      Yes
# 88872                          I am a developer by profession      Yes
# ...

# %%
df   ## It is not permanetly changed.
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...
