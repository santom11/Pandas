# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')
pd.set_option('display.max_columns',10)
pd.set_option('display.max_rows', 10)

# %%
dc    ##Sort an column
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 65615       66034                     I am a developer by profession       No
# 67561       67994  I am not primarily a developer, but I write co...      Yes
# 71011       71463                     I am a developer by profession      Yes
# 52344       52680             I am a student who is learning to code      Yes
# 63952       64361                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88874       88076                                                NaN       No
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
df.sort_values(by='Sexuality' , ascending=False)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 57709       58077  I am not primarily a developer, but I write co...      Yes
# 57715       58083                     I am a developer by profession      Yes
# 57714       58082                     I am a developer by profession      Yes
# 57713       58081                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88874       88076                                                NaN       No
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
df.sort_values(by=['Sexuality', 'Ethnicity'] , ascending=[False, True])  ##Once column asending and otherone desending
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 79             80  I am a developer by profession      Yes
# 807           810  I am a developer by profession      Yes
# 1378         1385  I am a developer by profession       No
# 1744         1752  I am a developer by profession      Yes
# 1876         1884  I am a developer by profession       No
# ...           ...                             ...      ...
# 88874       88076                             NaN       No
# 88878       88377                             NaN      Yes
# 88879       88601                             NaN       No
# 88880       88802                             NaN       No
# 88881       88816                             NaN       No
#
#                                              OpenSourcer  \
# 79     Less than once a month but more than once per ...
# 807    Less than once a month but more than once per ...
# 1378                                               Never
# ...

# %%
df.sort_index()
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False],inplace=True)

# %%
df[['Country' , 'ConvertedComp' ]].head(50)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# ...            ...            ...
# 3771       Albania       114550.0
# 9230       Albania        74474.0
# 6688       Albania        60000.0
# 10257      Albania        57300.0
# 65859      Albania        41244.0
#
# [50 rows x 2 columns]

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')  ## 10 largest from ConvertedComp
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 25833       25983                     I am a developer by profession      Yes
# 87353       87896                     I am a developer by profession      Yes
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 77665       78151                     I am a developer by profession      Yes
# 79701       80200                     I am a developer by profession      Yes
# 51798       52132                     I am a developer by profession      Yes
# 75088       75561                     I am a developer by profession      Yes
# 32056       32250                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
df.nsmallest(10, 'ConvertedComp')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 28470       28638                     I am a developer by profession      Yes
# 719           722                     I am a developer by profession       No
# 13760       13825                     I am a developer by profession      Yes
# 40655       40913                     I am a developer by profession      Yes
# 30447       30630                     I am a developer by profession      Yes
# 68611       69049                     I am a developer by profession       No
# 19235       19340  I am not primarily a developer, but I write co...      Yes
# 16126       16214  I am not primarily a developer, but I write co...      Yes
# 29184       29355                     I am a developer by profession      Yes
# 1678         1685                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...
